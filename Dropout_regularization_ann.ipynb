# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavKumar0000/Machine_learning_practice/blob/main/Dropout_regularization_ann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/sonar.all-data", header=None)
df.sample(5)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 116  0.0094  0.0333  0.0306  0.0376  0.1296  0.1795  0.1909  0.1692  0.1870
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 32   0.0195  0.0213  0.0058  0.0190  0.0319  0.0571  0.1004  0.0668  0.0691
# 164  0.0163  0.0198  0.0202  0.0386  0.0752  0.1444  0.1487  0.1484  0.2442
# 156  0.0047  0.0059  0.0080  0.0554  0.0883  0.1278  0.1674  0.1373  0.2922
#
#          9   ...      51      52      53      54      55      56      57  \
# 116  0.1725  ...  0.0153  0.0112  0.0241  0.0164  0.0055  0.0078  0.0055
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 32   0.0242  ...  0.0157  0.0074  0.0271  0.0203  0.0089  0.0095  0.0095
# 164  0.2822  ...  0.0077  0.0026  0.0031  0.0083  0.0020  0.0084  0.0108
# 156  0.3469  ...  0.0095  0.0126  0.0069  0.0039  0.0068  0.0060  0.0045
#
#          58      59  60
# 116  0.0091  0.0067   M
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
#        ...
# 56    float64
# 57    float64
# 58    float64
# 59    float64
# 60     object
# Length: 61, dtype: object

# %%
df[60].replace({'R':1,'M':0},inplace=True)

# %%
df.sample(5)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 150  0.0209  0.0278  0.0115  0.0445  0.0427  0.0766  0.1458  0.1430  0.1894
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 182  0.0095  0.0308  0.0539  0.0411  0.0613  0.1039  0.1016  0.1394  0.2592
# 143  0.0516  0.0944  0.0622  0.0415  0.0995  0.2431  0.1777  0.2018  0.2611
# 84   0.0378  0.0318  0.0423  0.0350  0.1787  0.1635  0.0887  0.0817  0.1779
#
#          9   ...      51      52      53      54      55      56      57  \
# 150  0.1853  ...  0.0096  0.0014  0.0049  0.0039  0.0029  0.0078  0.0047
# 2    0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 182  0.3745  ...  0.0181  0.0019  0.0102  0.0133  0.0040  0.0042  0.0030
# 143  0.1294  ...  0.0432  0.0274  0.0152  0.0120  0.0129  0.0020  0.0109
# 84   0.2053  ...  0.0046  0.0044  0.0078  0.0102  0.0065  0.0061  0.0062
#
#          58      59  60
# 150  0.0021  0.0011   0
# ...

# %%
df.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df[60].value_counts()
# Out:
# 60
# 0    111
# 1     97
# Name: count, dtype: int64

# %%
X = df.drop(60, axis=1)
y = df[60]

# %%
print(X.shape)
print(y.shape)
# Out:
# (208, 60)
# (208,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((156, 60), (52, 60))

# %% [markdown]
# Model without dropout layer

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(60, input_dim=60, activation='relu'),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4911 - loss: 0.6974
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6609 - loss: 0.6624
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6945 - loss: 0.6495
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7643 - loss: 0.6150
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6533 - loss: 0.5917
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7669 - loss: 0.5569
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8402 - loss: 0.4956
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7671 - loss: 0.5057
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8176 - loss: 0.4454
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8293 - loss: 0.4191
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8879 - loss: 0.3820
# Epoch 12/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7396 - loss: 1.1223
# [1.038549780845642, 0.75]

# %% [markdown]
# We can see trainig accuracy is so so much better than test accuracy which means its biased

# %%
y_pred = model.predict(X_test).reshape(-1)
print(y_pred[:10])

# round the values to nearest integer ie 0 or 1
y_pred = np.round(y_pred)
print(y_pred[:10])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# [3.6353814e-08 9.4437784e-01 9.8819762e-01 5.2202009e-05 9.9999982e-01
#  9.9968749e-01 2.2376841e-01 9.9999964e-01 2.6323360e-05 1.0000000e+00]
# [0. 1. 1. 0. 1. 1. 0. 1. 0. 1.]

# %%
y_test[:10]
# Out:
# 186    0
# 155    0
# 165    0
# 200    0
# 58     1
# 34     1
# 151    0
# 18     1
# 202    0
# 62     1
# Name: 60, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.89      0.79        27
#            1       0.83      0.60      0.70        25
#
#     accuracy                           0.75        52
#    macro avg       0.77      0.74      0.74        52
# weighted avg       0.77      0.75      0.74        52

# %% [markdown]
# Model with dropout layer

# %%
modeld = keras.Sequential([
    keras.layers.Dense(60, input_dim=60, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

modeld.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

modeld.fit(X_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4864 - loss: 0.7332
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5017 - loss: 0.7165
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5402 - loss: 0.6798
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4964 - loss: 0.7078
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5118 - loss: 0.7186
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5060 - loss: 0.7036
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4953 - loss: 0.7053
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5164 - loss: 0.7068
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4878 - loss: 0.7034
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6245 - loss: 0.6541
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5788 - loss: 0.6678
# Epoch 12/100
# ...

# %%
modeld.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7756 - loss: 0.4492
# [0.4221838712692261, 0.7884615659713745]

# %%
y_pred = modeld.predict(X_test).reshape(-1)
print(y_pred[:10])
# round the values to nearest integer ie 0 or 1
y_pred = np.round(y_pred)
print(y_pred[:10])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [3.0294750e-05 8.2611340e-01 9.5739329e-01 1.1301325e-02 9.9689859e-01
#  8.2847875e-01 3.7477073e-01 9.9357629e-01 1.4169895e-02 9.9775004e-01]
# [0. 1. 1. 0. 1. 1. 0. 1. 0. 1.]

# %%
y_test[:10]
# Out:
# 186    0
# 155    0
# 165    0
# 200    0
# 58     1
# 34     1
# 151    0
# 18     1
# 202    0
# 62     1
# Name: 60, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        27
#            1       0.82      0.72      0.77        25
#
#     accuracy                           0.79        52
#    macro avg       0.79      0.79      0.79        52
# weighted avg       0.79      0.79      0.79        52
